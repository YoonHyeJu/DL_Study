# %% [markdown]
# <a href="https://colab.research.google.com/github/YoonHyeJu/project1/blob/master/Yolo_KB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
# !git clone http://github.com/ultralytics/yolov3
# Out:
# Cloning into 'yolov3'...
# ...
# remote: Enumerating objects: 9437, done.
# remote: Total 9437 (delta 0), reused 0 (delta 0), pack-reused 9437
# Receiving objects: 100% (9437/9437), 7.81 MiB | 29.39 MiB/s, done.
# Resolving deltas: 100% (6469/6469), done.

# %%
# !cd yolov3

# %%
import os
a=os.listdir('/content/yolov3/data/data/images')
b=[]
for i in a:
    b.append(os.path.join('/content/yolov3/data/data/images', i))
    
with open('/content/yolov3/data/id.txt', 'w') as filehandle:
    
    for listitem in b:
        filehandle.write('%s\n' % listitem)

# %%
# !python3 /content/yolov3/train.py --cfg /content/yolov3/cfg/yolov3-tiny.cfg --data /content/yolov3/data/id.data --nosave
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='/content/yolov3/cfg/yolov3-tiny.cfg', data='/content/yolov3/data/id.data', device='', epochs=100, evolve=False, freeze_layers=False, img_size=[320, 640], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='/content/yolov3/weights/yolov3-tiny.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# 2020-08-26 11:51:00.432896: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 37 layers, 8.07261e+06 parameters, 8.07261e+06 gradients
# Optimizer groups: 13 .bias, 13 Conv2d.weight, 11 other
# ...

# %%
# !python3 /content/yolov3/detect.py --cfg /content/yolov3/cfg/yolov3-tiny.cfg --weights /content/yolov3/weights/last.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='/content/yolov3/cfg/yolov3-tiny.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='/content/yolov3/data/coco_id.names', output='/content/yolov3/output', save_txt=False, source='/content/yolov3/data/samples', view_img=False, weights='/content/yolov3/weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 37 layers, 8.07261e+06 parameters, 8.07261e+06 gradients
# image 1/3 /content/yolov3/data/samples/1.jpg: 512x384 3 sensitive_labels, Done. (0.005s)
# image 2/3 /content/yolov3/data/samples/bus.jpg: 512x384 Done. (0.005s)
# image 3/3 /content/yolov3/data/samples/zidane.jpg: 320x512 Done. (0.004s)
# Results saved to /content//content/yolov3/output
# Done. (0.181s)
