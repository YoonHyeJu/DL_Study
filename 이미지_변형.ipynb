# %% [markdown]
# <a href="https://colab.research.google.com/github/YoonHyeJu/project1/blob/master/%EC%9D%B4%EB%AF%B8%EC%A7%80_%EB%B3%80%ED%98%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6f110af9-8619-49a6-a44d-4586d7d1c06d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f110af9-8619-49a6-a44d-4586d7d1c06d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images.jpg to images.jpg

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('images.jpg')
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
plt.show()

expand = cv2.resize(image, None, fx=2.0,fy=2.0,interpolation = cv2.INTER_CUBIC)
plt.imshow(cv2.cvtColor(expand, cv2.COLOR_BGR2RGB))
plt.show()

shrink = cv2.resize(image, None, fx=0.8,fy=0.8,interpolation = cv2.INTER_AREA)
plt.imshow(cv2.cvtColor(shrink, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import numpy as np

height, width = image.shape[:2]

M = np.float32([[1,0,50], [0,1,50]])
dst = cv2.warpAffine(image, M, (width, height))

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()

# %%
#이미지 회전
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('images.jpg')

height, width = image.shape[:2]

M = cv2.getRotationMatrix2D((width/2, height/2), 90, 0.5)
dst = cv2.warpAffine(image,M,(width, height))

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
